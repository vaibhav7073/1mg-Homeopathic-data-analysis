# %%
import pandas as pd
import bs4
import requests
from bs4 import BeautifulSoup

# %%
headers={
    'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36 OPR/95.0.0.0'

}

# %%
final_data=[]

# %%
for page_number in range(1,21):
    url = f'https://www.1mg.com/categories/homeopathy-57?filter=true&pageNumber=+str(i)'
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'lxml')
    
    medicine_names = [medicines.text for medicines in soup.find_all('div', class_='style__pro-title___2QwJy')]
    bottle_size = [sizes.text for sizes in soup.find_all('div', class_='style__pack-size___2JQG7')]
    mrp = [m.text for m in soup.find_all('span', class_='style__discount-price___25Bya')]
    prices = [p.text for p in soup.find_all('div', class_='style__price-tag___cOxYc')]
    urls = [ur.find('a')['href'] for ur in soup.find_all('div', class_='style__product-box___liepi')]
    
    for i in range(len(medicine_names)):
        name = medicine_names[i]
        size = bottle_size[i]
        discount_price = mrp[i]
        price = prices[i]
        url = urls[i]
        
        final_data.append([name, size, discount_price, price, url])

df = pd.DataFrame(final_data, columns=['Medicine_name', 'size_of_the_bottle', 'MRP_of_the_bottle', 'Price_of_the_bottle', '1mg_url'])

# %%
df
# Out:
#                                           Medicine_name  \
# 0     Dr Willmar Schwabe India Berberis Aquifolium M...
# 1     Dr Willmar Schwabe Germany Cineraria Maritima ...
# 2     Dr Batra's Homeo+ Immunity Medicine Oral Drops...
# 3            SBL Arnica Montana Herbal Shampoo with TJC
# 4                     Boericke and Tafel Arnica Shampoo
# ...                                                 ...
# 1156          SBL Calcarea Fluorica Biochemic Tablet 6X
# 1157                          Bakson's Rheum Aid Tablet
# 1158           Bjain Phytolacca Berry Mother Tincture Q
# 1159                 SBL Arnica Montana Dilution 200 CH
# 1160         Dr. Reckeweg R5 Stomach and Digestion Drop
#
#                     size_of_the_bottle MRP_of_the_bottle Price_of_the_bottle  \
# 0      bottle of 30 ml Mother Tincture              ₹220                ₹189
# 1             bottle of 10 ml Eye Drop              ₹175                ₹151
# 2                      box of 1 Bottle              ₹199                ₹139
# 3             bottle of 200 ml Shampoo              ₹170                ₹146
# 4        pump bottle of 250 ml Shampoo              ₹200                ₹190
# ...                                ...               ...                 ...
# 1156  bottle of 25 gm Biochemic Tablet              ₹110                 ₹97
# 1157             bottle of 200 tablets              ₹500                ₹430
# 1158   bottle of 30 ml Mother Tincture              ₹240                ₹207
# 1159          bottle of 30 ml Dilution              ₹115                 ₹93
# 1160              bottle of 22 ml Drop              ₹270                ₹237
#
#                                                 1mg_url
# 0     /otc/dr-willmar-schwabe-india-berberis-aquifol...
# 1     /otc/dr-willmar-schwabe-germany-cineraria-mari...
# 2     /otc/dr-batra-s-homeo-immunity-medicine-oral-d...
# 3     /otc/sbl-arnica-montana-herbal-shampoo-with-tj...
# 4      /otc/boericke-and-tafel-arnica-shampoo-otc418583
# ...                                                 ...
# 1156  /otc/sbl-calcarea-fluorica-biochemic-tablet-6x...
# 1157           /otc/bakson-s-rheum-aid-tablet-otc386770
# 1158  /otc/bjain-phytolacca-berry-mother-tincture-q-...
# 1159  /otc/sbl-arnica-montana-dilution-200-ch-otc338216
# 1160  /otc/dr.-reckeweg-r5-stomach-and-digestion-dro...
#
# [1161 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Medicine_name          0
# size_of_the_bottle     0
# MRP_of_the_bottle      0
# Price_of_the_bottle    0
# 1mg_url                0
# dtype: int64

# %%
df.dtypes
# Out:
# Medicine_name          object
# size_of_the_bottle     object
# MRP_of_the_bottle      object
# Price_of_the_bottle    object
# 1mg_url                object
# dtype: object

# %%
for i in df.columns:
    print(i,df[i].sort_values().unique(),'\n',sep= '\n')
# Out:
# Medicine_name
# ['ADEL Ashwagandha Mother Tincture Q'
#  'ADEL Diacard Gold Madaus Drop Homeopathic Medicine'
#  'Adven Gall Set Drop' 'Allen A41 Memory Drop' 'Allen Fair Touch Cream'
#  "Bakson's Aller Aid Tablet" "Bakson's Fevo Aid Syrup"
#  "Bakson's Rheum Aid Tablet" "Bakson's Throat Aid Tablet"
#  "Bakson's Vitamin D Plus Capsule" "Bakson's Y-Lax Tablet"
#  'Bhargava Spondin Drop' 'Bjain Andrographis Paniculata Mother Tincture Q'
#  'Bjain Avena Sativa Mother Tincture Q'
#  'Bjain Baryta Carbonica Dilution 30 CH'
#  'Bjain Five Phos Biochemic Tablet 6X' 'Bjain Guatteria Gaumeri Drop'
#  'Bjain Lycopodium Clavatum Dilution 200 CH'
#  'Bjain Mercurius Iodatus Ruber Trituration Tablet 6X'
#  'Bjain Omeo Allergy Tablet' 'Bjain Omeo Arthritis Syrup'
#  'Bjain Omeo Ear Drop' 'Bjain Omeo Mouth Ulcer Tablet'
#  'Bjain Phytolacca Berry Mother Tincture Q'
#  'Boericke and Tafel Arnica Shampoo'
#  "Dr Batra's Homeo+ Immunity Medicine Oral Drops (30ml Each)"
#  'Dr Willmar Schwabe Germany Cineraria Maritima Schwabe Eye Drop Alcohol Free'
#  'Dr Willmar Schwabe Germany Cineraria Maritima Without Alcohol Eye Drop'
#  'Dr Willmar Schwabe India Alpha - Tons Tablet'
#  'Dr Willmar Schwabe India Berberis Aquifolium Mother Tincture Q'
#  'Dr Willmar Schwabe India Damiaplant Drop'
#  'Dr Willmar Schwabe India Ledum Palustre Dilution 200 CH'
#  'Dr Willmar Schwabe India Rosmarinus Officinalis Mother Tincture Q'
#  'Dr Willmar Schwabe India Thyroidinum Trituration Tablet 3X'
#  'Dr. Raj Vigoraj Oil' 'Dr. Reckeweg Berberis Vul Mother Tincture Q'
#  'Dr. Reckeweg Calcarea Phosphorica Biochemic Tablet 6X'
#  'Dr. Reckeweg Conium Mac Dilution 1000 CH'
#  'Dr. Reckeweg Drosera Dilution 30 CH'
#  'Dr. Reckeweg Iodium Dilution 30 CH'
#  'Dr. Reckeweg Petroleum Dilution 30 CH'
#  'Dr. Reckeweg Phytolacca Berry Mother Tincture Q'
#  'Dr. Reckeweg R13 Hemorrhoidal Drop'
#  'Dr. Reckeweg R40 Diabetes Drop Homeopathic Medicine'
#  'Dr. Reckeweg R41 Sexual Neurasthenia Drop'
#  'Dr. Reckeweg R5 Stomach and Digestion Drop'
#  '/otc/rxhomeo-belladonna-200c-pellets-otc758861'
#  '/otc/sbl-apis-mellifica-ointment-otc330979'
#  '/otc/sbl-arnica-montana-dilution-200-ch-otc338216'
#  '/otc/sbl-arnica-montana-hair-oil-with-tjc-otc330951'
#  '/otc/sbl-arnica-montana-herbal-shampoo-with-conditioner-otc329021'
#  '/otc/sbl-arnica-montana-herbal-shampoo-with-tjc-otc329025'
#  '/otc/sbl-bacillinum-dilution-1000-ch-otc345994'
#  '/otc/sbl-berberis-vulgaris-mother-tincture-q-otc348876'
#  '/otc/sbl-calcarea-fluorica-biochemic-tablet-6x-otc331087'
#  '/otc/sbl-cineraria-maritima-10-eye-drop-otc329014'
#  '/otc/sbl-clearstone-drop-otc326121'
#  '/otc/sbl-hyoscyamus-niger-dilution-200-ch-otc347945'
#  '/otc/sbl-jaborandi-hair-oil-otc329035'
#  '/otc/sbl-kali-muriaticum-dilution-200-ch-otc348045'
#  '/otc/sbl-kali-phosphoricum-biochemic-tablet-6x-otc331042'
#  '/otc/sbl-natrum-muriaticum-biochemic-tablet-3x-otc330937'
#  '/otc/sbl-nux-vomica-dilution-30-ch-otc338194'
#  '/otc/sbl-sarracenia-purpurea-dilution-1000-ch-otc358168'
#  '/otc/sbl-scalptone-tablet-otc326111'
#  '/otc/sbl-stobal-cough-syrup-otc328988'
#  '/otc/sbl-trombidium-dilution-200-ch-otc359448'
#  '/otc/similia-brahmi-mother-tincture-q-otc574325']

# %%
df['MRP_of_the_bottle']=df['MRP_of_the_bottle'].str.replace('₹','')

# %%
df['MRP_of_the_bottle']=df['MRP_of_the_bottle'].astype('int64')

# %%
df['Price_of_the_bottle']=df['Price_of_the_bottle'].str.replace('₹','')

# %%
df['Price_of_the_bottle']=df['Price_of_the_bottle'].str.replace('MRP','')

# %%
df['Price_of_the_bottle']=df['Price_of_the_bottle'].astype('int64')

# %%
df.dtypes
# Out:
# Medicine_name          object
# size_of_the_bottle     object
# MRP_of_the_bottle       int64
# Price_of_the_bottle     int64
# 1mg_url                object
# dtype: object

# %%
pd.DataFrame(df).to_csv("1Mg table1.csv",index = False)

# %% [markdown]
# # code for table-2

# %%
url_2="https://www.1mg.com"

# %%
r=requests.get("https://www.1mg.com/categories/homeopathy-57?filter=true&pageNumber=2",headers=headers)

# %%
soup= BeautifulSoup(r.content,"lxml")

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<!-- Chrome, Firefox OS, Opera and Vivaldi -->\n<html>\n <head>\n  <meta content="#FFF3E3" name="theme-color"/>\n  <!-- Windows Phone -->\n  <meta content="#FFF3E3" name="msapplication-navbutton-color"/>\n  <!-- iOS Safari -->\n  <meta content="#FFF3E3" name="apple-mobile-web-app-status-bar-style"/>\n  <meta content="yes" name="apple-mobile-web-app-capable"/>\n  <!--Newrelic Header-->\n  <!-- Application styles-->\n  <link href="/faviconRebrand.ico" rel="shortcut icon" type="image/x-icon"/>\n  <meta content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>\n  <meta content="099F7701BE7D0B79C7C51734FDC2A2D9" name="msvalidate.01"/>\n  <link href="/notifyvisitors_push/chrome/manifest.json" rel="manifest"/>\n  <!-- Apple Touch Icons-->\n  <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>\n  <link href="/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>\n  <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>\n  <link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>\n  <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>\n  <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>\n  <link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>\n  <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>\n  <link href="/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>\n  <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon"/>\n  <link href="/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed"/>\n  <link as="font" crossorigin="" href="https://assets.1mg.com/hkp/1.0.0/static/css/fonts/clearsans-1.00/WOFF2/ClearSans-Regular.woff2" rel="preload" type="font/woff2"/>\n  <style>\n   .affordable,.apple_store,.down_arrow,.google_play,.payment,.reliable,.right_arrow,.secure,.up_arrow{background:url(https://onemg.gumlet.io/jmjg62xhpbmgrxugqgwx.png) no-repeat}.affordable{background:url(https://onemg.gumlet.io/affordable-rebrand_ivgidq.svg) no-repeat;width:98px;height:98px}.apple_store{background-position:0 -100px;width:136px;height:47px}.down_arrow{background-position:0 -149px;width:14px;height:10px}.facebook{background:url(https://onemg.gumlet.io/vqpr5zx9ofpsyafjwwin.svg) no-repeat;width:27px;height:26px}.instagram{background:url(https://onemg.gumlet.io/wwynoy59i3iakt8te5xl.svg) no-repeat;width:27px;height:26px}.google_play{background-position:0 -189px;width:136px;height:41px}.linkedin{background:url(https://onemg.gumlet.io/hqfglkzkfxaxaypniixn.svg) no-repeat;width:27px;height:26px}.payment{background-position:0 -260px;width:153px;height:47px}.reliable{background:url(https://onemg.gumlet.io/secure-rebrand_x6f8yq.svg) no-repeat;width:98px;height:98px}.right_arrow{background-position:0 -409px;width:19px;height:19px}.secure{background:url(https://onemg.gumlet.io/reliable-rebrand_rcpof3.svg) no-repeat;width:98px;height:98px}.twitter{background:url(https://onemg.gumlet.io/cwrpdmlzckwzvv9e1gjv.svg) no-repeat;width:27px;height:26px}.up_arrow{background-position:0 -558px;width:14px;height:10px}.youtube{background:url(https://onemg.gumlet.io/tywtfwyzxb8ujnqmbuau.svg) no-repeat;width:26px;height:26px}.medium{background:url(https://onemg.gumlet.io/ny7nk9wxxlcxpeh1jbgg.svg) no-repeat;width:26px;height:26px}\n  </style>\n  <!-- styles-->\n  <style>\n   .homepage-container .main-content .content{max-width:100%;overflow:visible}.mob-search-landing{display:none;position:fixed;width:100%;top:0;left:0;bottom:0;right:0;height:100%;z-index:30;background:#f8f8f8;backface-visibility:hidden!important;-webkit-backface-visibility:hidden!important;-moz-backface-visibility:hidden!important}.mob-search-landing .search-clear-button{display:none;max-width:20px;float:right;cursor:pointer;margin-right:3px}.btn.btn-primary.btn-adding-to-cart .ch ...

# %%
diff_link_product=[]
for i in range (1,21):
    r=requests.get(f"https://www.1mg.com/categories/homeopathy-57?filter=true&pageNumber={i}",headers=headers)
    soup= BeautifulSoup(r.content,"lxml")
    productlist= soup.find_all("div",{"class":"col-md-3 col-sm-4 col-xs-6 style__container___1TL2R"})
    for product in productlist:
        
        for link in product.find_all("a",href=True):
            
            diff_link_product.append(url_2 + link["href"])

# %%
len(diff_link_product)
# Out:
# 1060

# %%
productlist=[]
for link in diff_link_product:
    r=requests.get(link,headers=headers)
    soup=BeautifulSoup(r.content,"lxml")
    try:
        product_name=soup.find("h1",class_="ProductTitle__product-title___3QMYH").text.strip()
    except:
        product_name:"Nan"
    try:    
        Brand_name=soup.find("div",class_="ProductTitle__manufacturer___sTfon").text.strip()
    except:
        Brand_name:"Nan"
        
    try:
         Rating=soup.find("div",class_="RatingDisplay__ratings-container___3oUuo").text.strip()
    except:
        Rating:"Nan"
    try:
         No_Rating=soup.find("span",class_="RatingDisplay__ratings-header___ZNj5b").text.strip()
    except:
         No_Rating:"Nan"
    try:
        product_details = soup.find_all('div', {'class': 'ProductDescription__description-content___A_qCZ'})

        key_benefits = product_details[0].find_all('li')
        key_benefits_list = [benefit.text.strip() for benefit in key_benefits]
    except:
        key_benefits_list:"Nan"
        
#     ['key_benefits_list'][0][:1]

           
    product={
        
        "Product_name":product_name,
        "Brand":Brand_name,
        "Rating":Rating,
        "No_Rating":No_Rating,
        "key_benefits_list":key_benefits_list
         }
    productlist.append(product)

# %%
len(productlist)
# Out:
# 1060

# %%
df1=pd.DataFrame(productlist)
df1
# Out:
#                                            Product_name  \
# 0     Dr Willmar Schwabe India Berberis Aquifolium M...
# 1     Dr Willmar Schwabe Germany Cineraria Maritima ...
# 2     Dr Batra's Homeo+ Immunity Medicine Oral Drops...
# 3            SBL Arnica Montana Herbal Shampoo with TJC
# 4                     Boericke and Tafel Arnica Shampoo
# ...                                                 ...
# 1055                       SBL Graphites Dilution 30 CH
# 1056                       SBL Graphites Dilution 30 CH
# 1057                       SBL Graphites Dilution 30 CH
# 1058                       SBL Graphites Dilution 30 CH
# 1059                       SBL Graphites Dilution 30 CH
#
#                                           Brand Rating     No_Rating  \
# 0              Dr Willmar Schwabe India Pvt Ltd    4.3   686 Ratings
# 1              Dr Willmar Schwabe India Pvt Ltd    4.6  1153 Ratings
# 2     Dr Batra Positive Health Products Limited    4.6  1153 Ratings
# 3                                   SBL Pvt Ltd    4.4   680 Ratings
# 4              Dr Willmar Schwabe India Pvt Ltd    4.3   231 Ratings
# ...                                         ...    ...           ...
# 1055                                SBL Pvt Ltd    4.5   168 Ratings
# 1056                                SBL Pvt Ltd    4.5   168 Ratings
# 1057                                SBL Pvt Ltd    4.5   168 Ratings
# 1058                                SBL Pvt Ltd    4.5   168 Ratings
# 1059                                SBL Pvt Ltd    4.5   168 Ratings
#
#                                       key_benefits_list
# 0     [It helps improve mood and energy levels, Reli...
# 1     [Seneciobicolor (cineraria maritima), It is an...
# 2     [Echinacea, Aconitum Nappelus, Sambucus Nigra,...
# 3     [It helps manage dull, dry and coarse hair, It...
# 4     [Arnica, Jaborandi, Salvia, Enhances local blo...
# ...                                                 ...
# 1055  [Graphites Trituration, Treats painful cough w...
# 1056  [Graphites Trituration, Treats painful cough w...
# 1057  [Graphites Trituration, Treats painful cough w...
# 1058  [Graphites Trituration, Treats painful cough w...
# 1059  [Graphites Trituration, Treats painful cough w...
#
# [1060 rows x 5 columns]

# %%
pd.DataFrame(df1).to_csv("1Mg table2.csv",index = False)

# %%
df1['Product_name'].nunique()
# Out:
# 524
